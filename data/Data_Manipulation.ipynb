# %% [markdown]
# # DATA

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("surveys.csv")

# %%
data.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df = pd.read_csv("surveys.csv", na_values=":", usecols=["month", "day", "year", "sex", "weight"])

# %%
df.head(10)
# Out:
#    month  day  year sex  weight
# 0      7   16  1977   M     NaN
# 1      7   16  1977   M     NaN
# 2      7   16  1977   F     NaN
# 3      7   16  1977   M     NaN
# 4      7   16  1977   M     NaN
# 5      7   16  1977   M     NaN
# 6      7   16  1977   F     NaN
# 7      7   16  1977   M     NaN
# 8      7   16  1977   F     NaN
# 9      7   16  1977   F     NaN

# %%
df.tail(11)
# Out:
#        month  day  year  sex  weight
# 35538     12   31  2002    M    68.0
# 35539     12   31  2002    F    23.0
# 35540     12   31  2002    F    31.0
# 35541     12   31  2002    F    29.0
# 35542     12   31  2002    F    34.0
# 35543     12   31  2002  NaN     NaN
# 35544     12   31  2002  NaN     NaN
# 35545     12   31  2002  NaN     NaN
# 35546     12   31  2002    F    14.0
# 35547     12   31  2002    M    51.0
# 35548     12   31  2002  NaN     NaN

# %%
df.describe()
# Out:
#               month           day          year        weight
# count  35549.000000  35549.000000  35549.000000  32283.000000
# mean       6.474022     16.105966   1990.475231     42.672428
# std        3.396583      8.256691      7.493355     36.631259
# min        1.000000      1.000000   1977.000000      4.000000
# 25%        4.000000      9.000000   1984.000000     20.000000
# 50%        6.000000     16.000000   1990.000000     37.000000
# 75%        9.000000     23.000000   1997.000000     48.000000
# max       12.000000     31.000000   2002.000000    280.000000

# %%
data.describe()
# Out:
#           record_id         month           day          year       plot_id  \
# count  35549.000000  35549.000000  35549.000000  35549.000000  35549.000000
# mean   17775.000000      6.474022     16.105966   1990.475231     11.397001
# std    10262.256696      3.396583      8.256691      7.493355      6.799406
# min        1.000000      1.000000      1.000000   1977.000000      1.000000
# 25%     8888.000000      4.000000      9.000000   1984.000000      5.000000
# 50%    17775.000000      6.000000     16.000000   1990.000000     11.000000
# 75%    26662.000000      9.000000     23.000000   1997.000000     17.000000
# max    35549.000000     12.000000     31.000000   2002.000000     24.000000
#
#        hindfoot_length        weight
# count     31438.000000  32283.000000
# mean         29.287932     42.672428
# std           9.564759     36.631259
# min           2.000000      4.000000
# 25%          21.000000     20.000000
# 50%          32.000000     37.000000
# ...

# %%
age = 42
first_name = 'Ahmed'

# %%
print(first_name)
# Out:
# Ahmed

# %%
print(age)
# Out:
# 42

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Ahmed is 42 years old

# %%
print("first_name", 'is', age, 'years old')
# Out:
# first_name is 42 years old

# %%
print(first_name, 'is',"cow", age, 'years old')
# Out:
# Ahmed is cow 42 years old

# %%
age = age +10
print(age)
# Out:
# 52

# %%
atom_name = 'helium'
print(atom_name[1])
# Out:
# e

# %%
atom_name = 'sodium'
print(atom_name[0:6])
# Out:
# sodium

# %%
print(len("berryllium"))
# Out:
# 10

# %%
hello = "greetings"
print(type(hello))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
hello = "how"+" "+"are"+" "+"you"+" "+"doing"
print(hello)
# Out:
# how are you doing

# %%
seperator = "R" *10
print(seperator)
# Out:
# RRRRRRRRRR

# %%
print('half is', 1 / 2.0)
print('three squared is', 3.0 ** 2)
# Out:
# half is 0.5
# three squared is 9.0

# %%
variable_one = 1
variable_two = 5 * variable_one
variable_one = 2
print('first is', variable_one, 'and second is', variable_two)
# Out:
# first is 2 and second is 5

# %%
print('before')
print()
print('after')
# Out:
# before
#
# after

# %%
result = print('example')
print('result of print is', result)
# Out:
# example
# result of print is None

# %%
print(max(1, 2, 3))
print(min('a', 'A', '0'))
# Out:
# 3
# 0

# %%
print(min("1", "a"))
# Out:
# 1

# %%
round(2.58)
# Out:
# 3

# %%
my_string = 'Hello world!'  

print(len(my_string))      
print(my_string.swapcase()) 

print(my_string.__len__())
# Out:
# 12
# hELLO WORLD!
# 12

# %%
print(my_string.isupper())         
print(my_string.upper())            

print(my_string.upper().isupper())
# Out:
# False
# HELLO WORLD!
# True

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
import math

print('pi is', math.pi)
print('cos(pi) is', math.cos(math.pi))
# Out:
# pi is 3.141592653589793
# cos(pi) is -1.0

# %%
from math import cos, pi

print('cos(pi) is', cos(pi))
# Out:
# cos(pi) is -1.0

# %%
print(type(52))
# Out:
# <class 'int'>

# %%
first_name = "ahmad"
age = 52
print(first_name)
print(age)
# Out:
# ahmad
# 52

# %%
print(type(first_name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(type(5-2))
# Out:
# <class 'int'>

# %%
full_name = 'Ahmed' 'Walsh'
print(full_name)
# Out:
# AhmedWalsh

# %%
separator = '=' * 10
print(separator)

# %%
separator = 4 * 10
print(separator)
# Out:
# 40

# %%
print(1 + int('2'))
print(str(1) + '3')
# Out:
# 3
# 13

# %%
print(max(1, 2, 3))
print(min('a', 'A', '0'))
# Out:
# 3
# 0

# %%
print(my_string.isupper())          
print(my_string.upper())            

print(my_string.upper().isupper())
# Out:
# False
# HELLO WORLD!
# True

# %%
time = [0, 5, 10, 15]
position = [0, 20, 200, 300]

plt.plot(time, position)
plt.xlabel('Distance (m)')
plt.ylabel('Time (s)')
# Out:
# Text(0, 0.5, 'Time (s)')

# %%
element = "carbon"

# %%
ele = list(element)
ele[0]="C"

# %%
ele
# Out:
# ['C', 'a', 'r', 'b', 'o', 'n']

# %%
' '.join(ele)
# Out:
# 'C a r b o n'

# %%
'*'.join(ele)
# Out:
# 'C*a*r*b*o*n'

# %%
print(element[-1])
# Out:
# n

# %%
element1 = 'fluorine'
print(element1[::2])
# Out:
# furn

# %%
element1 = 'fluorine'
print(element1[::-1])
# Out:
# eniroulf

# %%
element2= "salim"
print(element2[::-1])
# Out:
# milas

# %%
print(element1[0:2])
# Out:
# fl

# %%
for saz in (1, 20, 2):
    print(saz)
# Out:
# 1
# 20
# 2

# %%
grade = int(input("Enter your grade: "))
if grade >= 90: 
    print("grade is A")
elif grade >= 80:
    print("grade is B")
elif grade >= 70:
    print("grade is C")
elif grade >= 60:
    print("
# Out:
# Enter your grade:  80
# grade is B
