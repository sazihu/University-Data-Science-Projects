# %% [markdown]
# # Data Science Class - Date 3/26/2025

# %%
import pandas as pd

# %%
data = pd.read_csv("educ_figdp_1_Data.csv")

# %%
data.head()
# Out:
#    TIME                            GEO  \
# 0  2000  European Union (28 countries)
# 1  2001  European Union (28 countries)
# 2  2002  European Union (28 countries)
# 3  2003  European Union (28 countries)
# 4  2004  European Union (28 countries)
#
#                                             INDIC_ED Value Flag and Footnotes
# 0  Total public expenditure on education as % of ...     :                NaN
# 1  Total public expenditure on education as % of ...     :                NaN
# 2  Total public expenditure on education as % of ...  5.00                  e
# 3  Total public expenditure on education as % of ...  5.03                  e
# 4  Total public expenditure on education as % of ...  4.95                  e

# %%
data.tail()
# Out:
#      TIME      GEO                                           INDIC_ED Value  \
# 379  2007  Finland  Total public expenditure on education as % of ...  5.90
# 380  2008  Finland  Total public expenditure on education as % of ...  6.10
# 381  2009  Finland  Total public expenditure on education as % of ...  6.81
# 382  2010  Finland  Total public expenditure on education as % of ...  6.85
# 383  2011  Finland  Total public expenditure on education as % of ...  6.76
#
#     Flag and Footnotes
# 379                NaN
# 380                NaN
# 381                NaN
# 382                NaN
# 383                NaN

# %%
df = pd.read_csv("educ_figdp_1_Data.csv", na_values=':', usecols=['TIME', "GEO", "Value"])

# %%
df.describe()
# Out:
#               TIME       Value
# count   384.000000  361.000000
# mean   2005.500000    5.203989
# std       3.456556    1.021694
# min    2000.000000    2.880000
# 25%    2002.750000    4.620000
# 50%    2005.500000    5.060000
# 75%    2008.250000    5.660000
# max    2011.000000    8.810000

# %%
df.head()
# Out:
#    TIME                            GEO  Value
# 0  2000  European Union (28 countries)    NaN
# 1  2001  European Union (28 countries)    NaN
# 2  2002  European Union (28 countries)   5.00
# 3  2003  European Union (28 countries)   5.03
# 4  2004  European Union (28 countries)   4.95

# %%
df.tail()
# Out:
#      TIME      GEO  Value
# 379  2007  Finland   5.90
# 380  2008  Finland   6.10
# 381  2009  Finland   6.81
# 382  2010  Finland   6.85
# 383  2011  Finland   6.76

# %%
df['Value']
# Out:
# 0       NaN
# 1       NaN
# 2      5.00
# 3      5.03
# 4      4.95
#        ...
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, Length: 384, dtype: float64

# %%
df.Value
# Out:
# 0       NaN
# 1       NaN
# 2      5.00
# 3      5.03
# 4      4.95
#        ...
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, Length: 384, dtype: float64

# %%
df[10:14]
# Out:
#     TIME                            GEO  Value
# 10  2010  European Union (28 countries)   5.41
# 11  2011  European Union (28 countries)   5.25
# 12  2000  European Union (27 countries)   4.91
# 13  2001  European Union (27 countries)   4.99

# %%
df.loc[90:94, ['TIME', 'GEO']]
# Out:
#     TIME      GEO
# 90  2006  Belgium
# 91  2007  Belgium
# 92  2008  Belgium
# 93  2009  Belgium
# 94  2010  Belgium

# %%
df.iloc[90:94, [0,1]]
# Out:
#     TIME      GEO
# 90  2006  Belgium
# 91  2007  Belgium
# 92  2008  Belgium
# 93  2009  Belgium

# %%
#df_filter = df['Value'].where(df['Value'] > 6.5, other=0).tail()
#df_filter

df['Value'].where(df['Value'] > 6.5, other=0).tail()
# Out:
# 379    0.00
# 380    0.00
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, dtype: float64

# %%
df[df['Value'].isnull()].head()
# Out:
#     TIME                            GEO  Value
# 0   2000  European Union (28 countries)    NaN
# 1   2001  European Union (28 countries)    NaN
# 36  2000       Euro area (18 countries)    NaN
# 37  2001       Euro area (18 countries)    NaN
# 48  2000       Euro area (17 countries)    NaN

# %%
df.max(axis = 0)
# Out:
# TIME      2011
# GEO      Spain
# Value     8.81
# dtype: object

# %%
df[["TIME","Value","GEO"]].max()
# Out:
# TIME      2011
# Value     8.81
# GEO      Spain
# dtype: object

# %%
print("Pandas max function :\n", df['Value'].max(axis=0))
# Out:
# Pandas max function :
#  8.81

# %%
print("Python max function :\n", max(df['Value']))
# Out:
# Python max function :
#  nan

# %%
df_math = df['Value'] / 100
df_math.head()
# Out:
# 0       NaN
# 1       NaN
# 2    0.0500
# 3    0.0503
# 4    0.0495
# Name: Value, dtype: float64

# %%
import numpy as np
df_math1 = df['Value'].apply(np.sqrt)
df_math1.head()
# Out:
# 0         NaN
# 1         NaN
# 2    2.236068
# 3    2.242766
# 4    2.224860
# Name: Value, dtype: float64

# %%
import numpy as np
df_math1 = df['Value'].apply(lambda d: d**2)
df_math1.head()
# Out:
# 0        NaN
# 1        NaN
# 2    25.0000
# 3    25.3009
# 4    24.5025
# Name: Value, dtype: float64

# %%
df["ValueNorm"] = df["Value"]/df["Value"].max()
df.tail()
# Out:
#      TIME      GEO  Value  ValueNorm
# 379  2007  Finland   5.90   0.669694
# 380  2008  Finland   6.10   0.692395
# 381  2009  Finland   6.81   0.772985
# 382  2010  Finland   6.85   0.777526
# 383  2011  Finland   6.76   0.767310
